# %% [markdown]
# # **BirdCLEF 2025 Training Notebook**
#
# This is a baseline training pipeline for BirdCLEF 2025 using EfficientNetB0 with PyTorch and Timm(for pretrained EffNet). You can check inference and preprocessing notebooks in the following links:
#
# Note that by default this notebook is in Debug Mode, so it will only train the model with 2 epochs, but the [weight](https://www.kaggle.com/datasets/kadircandrisolu/birdclef25-effnetb0-starter-weight) I used in the inference notebook was obtained after 10 epochs of training.
#
# **Features**
# * Implement with Pytorch and Timm
# * Flexible audio processing with both pre-computed mel spectrograms
# * Stratified 5-fold cross-validation with ensemble capability
# * Mixup training for improved generalization
# * Spectrogram augmentations (time/frequency masking, brightness adjustment)
# * AdamW optimizer with Cosine Annealing LR scheduling
# * Debug mode for quick experimentation with smaller datasets
#
#
# Here is a list of new experiments (features) that were built on top of this baseline notebook:
#
# | **Change Type**                            | **Public LB Score** | **Private LB Score** | **Explanation**                                                            |
# |--------------------------------------------|----------------------|-----------------------|----------------------------------------------------------------------------|
# | Baseline                                   | 0.761                | 0.748                 | Baseline                                                                   |
# | 1 model, no CV                  | 0.785                | 0.782                 | Inference on only 1 model without cross-validation                         |
# | Switch to nfnet, 1 model                   | 0.782                | 0.785                 | Switched to nfnet model, single model                                      |
# | Ensemble of 3 eca_nfnet_l0                 | 0.804                | 0.814                 | Ensemble of 3 eca_nfnet_l0 models                                          |
# | Ensemble of eca_nfnet_l0 & eca_nfnet_l1    | 0.790                | 0.795                 | Ensemble of a single eca_nfnet_l0 and single eca_nfnet_l1 models           |
# | Pseudo labelling                         | 0.816                | 0.809                 | Pseudo-labelling added in training                                         |
#
#
#
# We also tried other experiments, but didn't submit them to the competition due to poor validation results. We also explain that in the report.

# %% [markdown]
# ## Libraries

# %%
import os
import logging
import random
import gc
import time
import cv2
import math
import warnings
from pathlib import Path

import numpy as np
import pandas as pd
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import roc_auc_score
import librosa

import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.optim import lr_scheduler
from torch.utils.data import Dataset, DataLoader

import matplotlib.pyplot as plt
import seaborn as sns
from tqdm.auto import tqdm

import timm

warnings.filterwarnings("ignore")
logging.basicConfig(level=logging.ERROR)

# %% [markdown]
# ## Configuration

# %%
class CFG:
    
    seed = 42
    debug = True  
    apex = False
    print_freq = 100
    num_workers = 2
    
    OUTPUT_DIR = '/kaggle/working/'

    train_datadir = '/kaggle/input/birdclef-2025/train_audio'
    train_csv = '/kaggle/input/birdclef-2025/train.csv'
    test_soundscapes = '/kaggle/input/birdclef-2025/test_soundscapes'
    submission_csv = '/kaggle/input/birdclef-2025/sample_submission.csv'
    taxonomy_csv = '/kaggle/input/birdclef-2025/taxonomy.csv'

    spectrogram_npy = '/kaggle/input/k/jakobjere/transforming-audio-to-mel-spec-birdclef-25/birdclef2025_melspec_test.npy'

    TARGET_DURATION = 5.0
    TARGET_SHAPE = (256, 256)

    model_name = 'efficientnet_b0'  
    pretrained = True
    in_channels = 1

    device = 'cuda' if torch.cuda.is_available() else 'cpu'
    epochs = 10  
    batch_size = 32  
    criterion = 'BCEWithLogitsLoss'

    n_fold = 5
    selected_folds = [0, 1, 2, 3, 4]   

    optimizer = 'AdamW'
    lr = 5e-4 
    weight_decay = 1e-5
  
    scheduler = 'CosineAnnealingLR'
    min_lr = 1e-6
    T_max = epochs

    aug_prob = 0.5  
    mixup_alpha = 0.5  
    
    def update_debug_settings(self):
        if self.debug:
            self.epochs = 2
            self.selected_folds = [0]

cfg = CFG()

# %% [markdown]
# ## Utilities

# %%
def set_seed(seed=42):
    """
    Set seed for reproducibility
    """
    random.seed(seed)
    os.environ["PYTHONHASHSEED"] = str(seed)
    np.random.seed(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.cuda.manual_seed_all(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = False

set_seed(cfg.seed)

# %% [markdown]
# ## Dataset Preparation and Data Augmentations
# We'll convert audio to mel spectrograms and apply random augmentations with 50% probability each - including time stretching, pitch shifting, and volume adjustments. This randomized approach creates diverse training samples from the same audio files

# %%
class BirdCLEFDatasetFromNPY(Dataset):
    def __init__(self, df, cfg, spectrograms=None, mode="train"):
        self.df = df
        self.cfg = cfg
        self.mode = mode

        self.spectrograms = spectrograms
        
        taxonomy_df = pd.read_csv(self.cfg.taxonomy_csv)
        self.species_ids = taxonomy_df['primary_label'].tolist()
        self.num_classes = len(self.species_ids)
        self.label_to_idx = {label: idx for idx, label in enumerate(self.species_ids)}

        if 'filepath' not in self.df.columns:
            self.df['filepath'] = self.cfg.train_datadir + '/' + self.df.filename
        
        if 'samplename' not in self.df.columns:
            self.df['samplename'] = self.df.filename.map(lambda x: x.split('/')[0] + '-' + x.split('/')[-1].split('.')[0])

        sample_names = set(self.df['samplename'])
        if self.spectrograms:
            found_samples = sum(1 for name in sample_names if name in self.spectrograms)
            print(f"Found {found_samples} matching spectrograms for {mode} dataset out of {len(self.df)} samples")
        
        if cfg.debug:
            self.df = self.df.sample(min(1000, len(self.df)), random_state=cfg.seed).reset_index(drop=True)
    
    def __len__(self):
        return len(self.df)
    
    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        samplename = row['samplename']
        spec = None

        if self.spectrograms and samplename in self.spectrograms:
            spec = self.spectrograms[samplename]

        if spec is None:
            spec = np.zeros(self.cfg.TARGET_SHAPE, dtype=np.float32)
            if self.mode == "train":  # Only print warning during training
                print(f"Warning: Spectrogram for {samplename} not found and could not be generated")

        spec = torch.tensor(spec, dtype=torch.float32).unsqueeze(0)  # Add channel dimension

        if self.mode == "train" and random.random() < self.cfg.aug_prob:
            spec = self.apply_spec_augmentations(spec)
        
        target = self.encode_label(row['primary_label'])
        
        if 'secondary_labels' in row and row['secondary_labels'] not in [[''], None, np.nan]:
            if isinstance(row['secondary_labels'], str):
                secondary_labels = eval(row['secondary_labels'])
            else:
                secondary_labels = row['secondary_labels']
            
            for label in secondary_labels:
                if label in self.label_to_idx:
                    target[self.label_to_idx[label]] = 1.0
        
        return {
            'melspec': spec, 
            'target': torch.tensor(target, dtype=torch.float32),
            'filename': row['filename']
        }
    
    def apply_spec_augmentations(self, spec):
        """Apply augmentations to spectrogram"""
    
        # Time masking (horizontal stripes)
        if random.random() < 0.5:
            num_masks = random.randint(1, 3)
            for _ in range(num_masks):
                width = random.randint(5, 20)
                start = random.randint(0, spec.shape[2] - width)
                spec[0, :, start:start+width] = 0
        
        # Frequency masking (vertical stripes)
        if random.random() < 0.5:
            num_masks = random.randint(1, 3)
            for _ in range(num_masks):
                height = random.randint(5, 20)
                start = random.randint(0, spec.shape[1] - height)
                spec[0, start:start+height, :] = 0
        
        # Random brightness/contrast
        if random.random() < 0.5:
            gain = random.uniform(0.8, 1.2)
            bias = random.uniform(-0.1, 0.1)
            spec = spec * gain + bias
            spec = torch.clamp(spec, 0, 1) 
            
        return spec
    
    def encode_label(self, label):
        """Encode label to one-hot vector"""
        target = np.zeros(self.num_classes)
        if label in self.label_to_idx:
            target[self.label_to_idx[label]] = 1.0
        return target

# %%
def collate_fn(batch):
    """Custom collate function to handle different sized spectrograms"""
    batch = [item for item in batch if item is not None]
    if len(batch) == 0:
        return {}
        
    result = {key: [] for key in batch[0].keys()}
    
    for item in batch:
        for key, value in item.items():
            result[key].append(value)
    
    for key in result:
        if key == 'target' and isinstance(result[key][0], torch.Tensor):
            result[key] = torch.stack(result[key])
        elif key == 'melspec' and isinstance(result[key][0], torch.Tensor):
            shapes = [t.shape for t in result[key]]
            if len(set(str(s) for s in shapes)) == 1:
                result[key] = torch.stack(result[key])
    
    return result

# %% [markdown]
# ## Model Definition

# %%
class BirdCLEFModel(nn.Module):
    def __init__(self, cfg):
        super().__init__()
        self.cfg = cfg
        
        taxonomy_df = pd.read_csv(cfg.taxonomy_csv)
        cfg.num_classes = len(taxonomy_df)
        
        self.backbone = timm.create_model(
            cfg.model_name,
            pretrained=cfg.pretrained,
            in_chans=cfg.in_channels,
            drop_rate=0.2,
            drop_path_rate=0.2
        )
        
        if 'efficientnet' in cfg.model_name:
            backbone_out = self.backbone.classifier.in_features
            self.backbone.classifier = nn.Identity()
        elif 'resnet' in cfg.model_name:
            backbone_out = self.backbone.fc.in_features
            self.backbone.fc = nn.Identity()
        else:
            backbone_out = self.backbone.get_classifier().in_features
            self.backbone.reset_classifier(0, '')
        
        self.pooling = nn.AdaptiveAvgPool2d(1)
            
        self.feat_dim = backbone_out
        
        self.classifier = nn.Linear(backbone_out, cfg.num_classes)
        
        self.mixup_enabled = hasattr(cfg, 'mixup_alpha') and cfg.mixup_alpha > 0
        if self.mixup_enabled:
            self.mixup_alpha = cfg.mixup_alpha
            
    def forward(self, x, targets=None):
    
        if self.training and self.mixup_enabled and targets is not None:
            mixed_x, targets_a, targets_b, lam = self.mixup_data(x, targets)
            x = mixed_x
        else:
            targets_a, targets_b, lam = None, None, None
        
        features = self.backbone(x)
        
        if isinstance(features, dict):
            features = features['features']
            
        if len(features.shape) == 4:
            features = self.pooling(features)
            features = features.view(features.size(0), -1)
        
        logits = self.classifier(features)
        
        if self.training and self.mixup_enabled and targets is not None:
            loss = self.mixup_criterion(F.binary_cross_entropy_with_logits, 
                                       logits, targets_a, targets_b, lam)
            return logits, loss
            
        return logits
    
    def mixup_data(self, x, targets):
        """Applies mixup to the data batch"""
        batch_size = x.size(0)

        lam = np.random.beta(self.mixup_alpha, self.mixup_alpha)

        indices = torch.randperm(batch_size).to(x.device)

        mixed_x = lam * x + (1 - lam) * x[indices]
        
        return mixed_x, targets, targets[indices], lam
    
    def mixup_criterion(self, criterion, pred, y_a, y_b, lam):
        """Applies mixup to the loss function"""
        return lam * criterion(pred, y_a) + (1 - lam) * criterion(pred, y_b)

# %% [markdown]
# ## Training Utilities
# We are configuring our optimization strategy with the AdamW optimizer, cosine scheduling, and the BCEWithLogitsLoss criterion.

# %%
def get_optimizer(model, cfg):
  
    if cfg.optimizer == 'Adam':
        optimizer = optim.Adam(
            model.parameters(),
            lr=cfg.lr,
            weight_decay=cfg.weight_decay
        )
    elif cfg.optimizer == 'AdamW':
        optimizer = optim.AdamW(
            model.parameters(),
            lr=cfg.lr,
            weight_decay=cfg.weight_decay
        )
    elif cfg.optimizer == 'SGD':
        optimizer = optim.SGD(
            model.parameters(),
            lr=cfg.lr,
            momentum=0.9,
            weight_decay=cfg.weight_decay
        )
    else:
        raise NotImplementedError(f"Optimizer {cfg.optimizer} not implemented")
        
    return optimizer

def get_scheduler(optimizer, cfg):
   
    if cfg.scheduler == 'CosineAnnealingLR':
        scheduler = lr_scheduler.CosineAnnealingLR(
            optimizer,
            T_max=cfg.T_max,
            eta_min=cfg.min_lr
        )
    elif cfg.scheduler == 'ReduceLROnPlateau':
        scheduler = lr_scheduler.ReduceLROnPlateau(
            optimizer,
            mode='min',
            factor=0.5,
            patience=2,
            min_lr=cfg.min_lr,
            verbose=True
        )
    elif cfg.scheduler == 'StepLR':
        scheduler = lr_scheduler.StepLR(
            optimizer,
            step_size=cfg.epochs // 3,
            gamma=0.5
        )
    elif cfg.scheduler == 'OneCycleLR':
        scheduler = None  
    else:
        scheduler = None
        
    return scheduler

def get_criterion(cfg):
 
    if cfg.criterion == 'BCEWithLogitsLoss':
        criterion = nn.BCEWithLogitsLoss()
    else:
        raise NotImplementedError(f"Criterion {cfg.criterion} not implemented")
        
    return criterion

# %% [markdown]
# ## Training Loop

# %%
def train_one_epoch(model, loader, optimizer, criterion, device, scheduler=None):
    
    model.train()
    losses = []
    all_targets = []
    all_outputs = []
    
    pbar = tqdm(enumerate(loader), total=len(loader), desc="Training")
    
    for step, batch in pbar:
    
        if isinstance(batch['melspec'], list):
            batch_outputs = []
            batch_losses = []
            
            for i in range(len(batch['melspec'])):
                inputs = batch['melspec'][i].unsqueeze(0).to(device)
                target = batch['target'][i].unsqueeze(0).to(device)
                
                optimizer.zero_grad()
                output = model(inputs)
                loss = criterion(output, target)
                loss.backward()
                
                batch_outputs.append(output.detach().cpu())
                batch_losses.append(loss.item())
            
            optimizer.step()
            outputs = torch.cat(batch_outputs, dim=0).numpy()
            loss = np.mean(batch_losses)
            targets = batch['target'].numpy()
            
        else:
            inputs = batch['melspec'].to(device)
            targets = batch['target'].to(device)
            
            optimizer.zero_grad()
            outputs = model(inputs)
            
            if isinstance(outputs, tuple):
                outputs, loss = outputs  
            else:
                loss = criterion(outputs, targets)
                
            loss.backward()
            optimizer.step()
            
            outputs = outputs.detach().cpu().numpy()
            targets = targets.detach().cpu().numpy()
        
        if scheduler is not None and isinstance(scheduler, lr_scheduler.OneCycleLR):
            scheduler.step()
            
        all_outputs.append(outputs)
        all_targets.append(targets)
        losses.append(loss if isinstance(loss, float) else loss.item())
        
        pbar.set_postfix({
            'train_loss': np.mean(losses[-10:]) if losses else 0,
            'lr': optimizer.param_groups[0]['lr']
        })
    
    all_outputs = np.concatenate(all_outputs)
    all_targets = np.concatenate(all_targets)
    auc = calculate_auc(all_targets, all_outputs)
    avg_loss = np.mean(losses)
    
    return avg_loss, auc

def validate(model, loader, criterion, device):
   
    model.eval()
    losses = []
    all_targets = []
    all_outputs = []
    
    with torch.no_grad():
        for batch in tqdm(loader, desc="Validation"):
            if isinstance(batch['melspec'], list):
                batch_outputs = []
                batch_losses = []
                
                for i in range(len(batch['melspec'])):
                    inputs = batch['melspec'][i].unsqueeze(0).to(device)
                    target = batch['target'][i].unsqueeze(0).to(device)
                    
                    output = model(inputs)
                    loss = criterion(output, target)
                    
                    batch_outputs.append(output.detach().cpu())
                    batch_losses.append(loss.item())
                
                outputs = torch.cat(batch_outputs, dim=0).numpy()
                loss = np.mean(batch_losses)
                targets = batch['target'].numpy()
                
            else:
                inputs = batch['melspec'].to(device)
                targets = batch['target'].to(device)
                
                outputs = model(inputs)
                loss = criterion(outputs, targets)
                
                outputs = outputs.detach().cpu().numpy()
                targets = targets.detach().cpu().numpy()
            
            all_outputs.append(outputs)
            all_targets.append(targets)
            losses.append(loss if isinstance(loss, float) else loss.item())
    
    all_outputs = np.concatenate(all_outputs)
    all_targets = np.concatenate(all_targets)
    
    auc = calculate_auc(all_targets, all_outputs)
    avg_loss = np.mean(losses)
    
    return avg_loss, auc

def calculate_auc(targets, outputs):
  
    num_classes = targets.shape[1]
    aucs = []
    
    probs = 1 / (1 + np.exp(-outputs))
    
    for i in range(num_classes):
        
        if np.sum(targets[:, i]) > 0:
            class_auc = roc_auc_score(targets[:, i], probs[:, i])
            aucs.append(class_auc)
    
    return np.mean(aucs) if aucs else 0.0

# %% [markdown]
# ## Training!

# %%
def run_training(df, cfg):
    """Training function that can either use pre-computed spectrograms or generate them on-the-fly"""

    taxonomy_df = pd.read_csv(cfg.taxonomy_csv)
    species_ids = taxonomy_df['primary_label'].tolist()
    cfg.num_classes = len(species_ids)
    
    if cfg.debug:
        cfg.update_debug_settings()

    spectrograms = None
    print("Loading pre-computed mel spectrograms from NPY file...")
    try:
        spectrograms = np.load(cfg.spectrogram_npy, allow_pickle=True).item()
        print(f"Loaded {len(spectrograms)} pre-computed mel spectrograms")
    except Exception as e:
        print(f"Error loading pre-computed spectrograms: {e}")
        print("Will generate spectrograms on-the-fly instead.")    
        
    skf = StratifiedKFold(n_splits=cfg.n_fold, shuffle=True, random_state=cfg.seed)
    
    best_scores = []
    
    for fold, (train_idx, val_idx) in enumerate(skf.split(df, df['primary_label'])):
        if fold not in cfg.selected_folds:
            continue
            
        print(f'\n{"="*30} Fold {fold} {"="*30}')
        
        train_df = df.iloc[train_idx].reset_index(drop=True)
        val_df = df.iloc[val_idx].reset_index(drop=True)
        
        print(f'Training set: {len(train_df)} samples')
        print(f'Validation set: {len(val_df)} samples')
        
        train_dataset = BirdCLEFDatasetFromNPY(train_df, cfg, spectrograms=spectrograms, mode='train')
        val_dataset = BirdCLEFDatasetFromNPY(val_df, cfg, spectrograms=spectrograms, mode='valid')
        
        train_loader = DataLoader(
            train_dataset, 
            batch_size=cfg.batch_size, 
            shuffle=True, 
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn,
            drop_last=True
        )
        
        val_loader = DataLoader(
            val_dataset, 
            batch_size=cfg.batch_size, 
            shuffle=False, 
            num_workers=cfg.num_workers,
            pin_memory=True,
            collate_fn=collate_fn
        )
        
        model = BirdCLEFModel(cfg).to(cfg.device)
        optimizer = get_optimizer(model, cfg)
        criterion = get_criterion(cfg)
        
        if cfg.scheduler == 'OneCycleLR':
            scheduler = lr_scheduler.OneCycleLR(
                optimizer,
                max_lr=cfg.lr,
                steps_per_epoch=len(train_loader),
                epochs=cfg.epochs,
                pct_start=0.1
            )
        else:
            scheduler = get_scheduler(optimizer, cfg)
        
        best_auc = 0
        best_epoch = 0
        
        for epoch in range(cfg.epochs):
            print(f"\nEpoch {epoch+1}/{cfg.epochs}")
            
            train_loss, train_auc = train_one_epoch(
                model, 
                train_loader, 
                optimizer, 
                criterion, 
                cfg.device,
                scheduler if isinstance(scheduler, lr_scheduler.OneCycleLR) else None
            )
            
            val_loss, val_auc = validate(model, val_loader, criterion, cfg.device)

            if scheduler is not None and not isinstance(scheduler, lr_scheduler.OneCycleLR):
                if isinstance(scheduler, lr_scheduler.ReduceLROnPlateau):
                    scheduler.step(val_loss)
                else:
                    scheduler.step()

            print(f"Train Loss: {train_loss:.4f}, Train AUC: {train_auc:.4f}")
            print(f"Val Loss: {val_loss:.4f}, Val AUC: {val_auc:.4f}")
            
            if val_auc > best_auc:
                best_auc = val_auc
                best_epoch = epoch + 1
                print(f"New best AUC: {best_auc:.4f} at epoch {best_epoch}")

                torch.save({
                    'model_state_dict': model.state_dict(),
                    'optimizer_state_dict': optimizer.state_dict(),
                    'scheduler_state_dict': scheduler.state_dict() if scheduler else None,
                    'epoch': epoch,
                    'val_auc': val_auc,
                    'train_auc': train_auc,
                    'cfg': cfg
                }, f"model_fold{fold}.pth")
        
        best_scores.append(best_auc)
        print(f"\nBest AUC for fold {fold}: {best_auc:.4f} at epoch {best_epoch}")
        
        # Clear memory
        del model, optimizer, scheduler, train_loader, val_loader
        torch.cuda.empty_cache()
        gc.collect()
    
    print("\n" + "="*60)
    print("Cross-Validation Results:")
    for fold, score in enumerate(best_scores):
        print(f"Fold {cfg.selected_folds[fold]}: {score:.4f}")
    print(f"Mean AUC: {np.mean(best_scores):.4f}")
    print("="*60)

# %%
if __name__ == "__main__":
    import time
    
    print("\nLoading training data...")
    train_df = pd.read_csv(cfg.train_csv)
    taxonomy_df = pd.read_csv(cfg.taxonomy_csv)

    print("\nStarting training...")
    print("Using pre-computed mel spectrograms from NPY file")
    
    run_training(train_df, cfg)
    
    print("\nTraining complete!")
# Out:
# Loading training data...
#
# Starting training...
# Using pre-computed mel spectrograms from NPY file
# Loading pre-computed mel spectrograms from NPY file...
# Loaded 5 pre-computed mel spectrograms
#
# ============================== Fold 0 ==============================
# Training set: 22851 samples
# Validation set: 5713 samples
# Found 3 matching spectrograms for train dataset out of 22851 samples
# Found 2 matching spectrograms for valid dataset out of 5713 samples
# model.safetensors:   0%|          | 0.00/21.4M [00:00<?, ?B/s]
# Epoch 1/2
# Warning: Spectrogram for yelori1-XC454251 not found and could not be generated
# Training:   0%|          | 0/31 [00:00<?, ?it/s]
# Warning: Spectrogram for yeofly1-XC428310 not found and could not be generated
#
# Warning: Spectrogram for compot1-XC355993 not found and could not be generated
# Warning: Spectrogram for rumfly1-XC9196 not found and could not be generatedWarning: Spectrogram for yelori1-XC213024 not found and could not be generated
#
# Warning: Spectrogram for yebfly1-XC830728 not found and could not be generated
# Warning: Spectrogram for tbsfin1-iNat68779 not found and could not be generated
# Warning: Spectrogram for rutjac1-XC754909 not found and could not be generated
# Warning: Spectrogram for blchaw1-XC656900 not found and could not be generatedWarning: Spectrogram for ywcpar-XC245509 not found and could not be generated
#
# Warning: Spectrogram for 52884-CSA35124 not found and could not be generatedWarning: Spectrogram for trokin-iNat1125462 not found and could not be generated
#
# Warning: Spectrogram for blbwre1-XC11515 not found and could not be generatedWarning: Spectrogram for yebela1-iNat1099348 not found and could not be generated
#
# Warning: Spectrogram for blbwre1-XC10569 not found and could not be generatedWarning: Spectrogram for bobfly1-iNat992411 not found and could not be generated
#
# Warning: Spectrogram for compau-XC247997 not found and could not be generated
# Warning: Spectrogram for roahaw-XC257195 not found and could not be generated
# Warning: Spectrogram for strcuc1-iNat333763 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC939939 not found and could not be generatedWarning: Spectrogram for rutjac1-XC2695 not found and could not be generated
#
# Warning: Spectrogram for socfly1-iNat918247 not found and could not be generatedWarning: Spectrogram for trokin-XC611127 not found and could not be generated
#
# Warning: Spectrogram for linwoo1-XC176365 not found and could not be generatedWarning: Spectrogram for socfly1-iNat546244 not found and could not be generated
#
# Warning: Spectrogram for whtdov-XC608631 not found and could not be generatedWarning: Spectrogram for ampkin1-XC125511 not found and could not be generated
#
# Warning: Spectrogram for compau-XC388085 not found and could not be generated
# Warning: Spectrogram for cinbec1-XC389682 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC388387 not found and could not be generatedWarning: Spectrogram for bobfly1-iNat717379 not found and could not be generated
#
# Warning: Spectrogram for trokin-XC57674 not found and could not be generated
# Warning: Spectrogram for blchaw1-XC84953 not found and could not be generated
# Warning: Spectrogram for thbeup1-XC737983 not found and could not be generated
# Warning: Spectrogram for grekis-iNat456498 not found and could not be generated
# Warning: Spectrogram for cocwoo1-iNat650332 not found and could not be generated
# Warning: Spectrogram for strcuc1-XC409945 not found and could not be generated
# Warning: Spectrogram for soulap1-iNat456621 not found and could not be generatedWarning: Spectrogram for 41663-iNat480453 not found and could not be generated
#
# Warning: Spectrogram for bobfly1-iNat1225326 not found and could not be generatedWarning: Spectrogram for greani1-XC955828 not found and could not be generated
#
# Warning: Spectrogram for laufal1-iNat124754 not found and could not be generatedWarning: Spectrogram for whmtyr1-XC427097 not found and could not be generated
#
# Warning: Spectrogram for rumfly1-XC956038 not found and could not be generatedWarning: Spectrogram for gycwor1-XC290412 not found and could not be generated
#
# Warning: Spectrogram for bkcdon-XC602719 not found and could not be generatedWarning: Spectrogram for gycwor1-XC206719 not found and could not be generated
#
# Warning: Spectrogram for whbant1-XC465901 not found and could not be generatedWarning: Spectrogram for 41663-iNat329514 not found and could not be generated
#
# Warning: Spectrogram for yebela1-XC769092 not found and could not be generatedWarning: Spectrogram for roahaw-XC117319 not found and could not be generated
#
# Warning: Spectrogram for socfly1-iNat372032 not found and could not be generatedWarning: Spectrogram for thbeup1-XC762549 not found and could not be generated
#
# Warning: Spectrogram for yercac1-XC9294 not found and could not be generatedWarning: Spectrogram for compot1-XC479991 not found and could not be generated
#
# Warning: Spectrogram for paltan1-XC837430 not found and could not be generatedWarning: Spectrogram for roahaw-XC117546 not found and could not be generated
#
# Warning: Spectrogram for grbhaw1-XC50582 not found and could not be generated
# Warning: Spectrogram for soulap1-iNat50784 not found and could not be generated
# Warning: Spectrogram for whbant1-XC664405 not found and could not be generatedWarning: Spectrogram for soulap1-XC144878 not found and could not be generated
#
# Warning: Spectrogram for bbwduc-XC317158 not found and could not be generated
# Warning: Spectrogram for smbani-XC387590 not found and could not be generated
# Warning: Spectrogram for trsowl-iNat151180 not found and could not be generated
# Warning: Spectrogram for sobtyr1-XC247195 not found and could not be generatedWarning: Spectrogram for 41663-iNat1240392 not found and could not be generated
#
# Warning: Spectrogram for bucmot3-XC544556 not found and could not be generated
# Warning: Spectrogram for socfly1-XC233729 not found and could not be generated
# Warning: Spectrogram for crcwoo1-XC63210 not found and could not be generatedWarning: Spectrogram for banana-XC382368 not found and could not be generated
#
# Warning: Spectrogram for strfly1-XC599219 not found and could not be generated
# Warning: Spectrogram for rinkin1-iNat397660 not found and could not be generated
# Warning: Spectrogram for creoro1-XC132042 not found and could not be generatedWarning: Spectrogram for labter1-XC244963 not found and could not be generated
#
# Warning: Spectrogram for littin1-XC1943 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC610515 not found and could not be generatedWarning: Spectrogram for roahaw-iNat653763 not found and could not be generated
#
# Warning: Spectrogram for trokin-XC460842 not found and could not be generatedWarning: Spectrogram for wbwwre1-XC956669 not found and could not be generated
#
# Warning: Spectrogram for 21211-iNat998468 not found and could not be generatedWarning: Spectrogram for tropar-XC235229 not found and could not be generated
#
# Warning: Spectrogram for saffin-XC84694 not found and could not be generatedWarning: Spectrogram for compot1-iNat1187802 not found and could not be generated
#
# Warning: Spectrogram for bobher1-XC657819 not found and could not be generatedWarning: Spectrogram for yeofly1-XC859242 not found and could not be generated
#
# Warning: Spectrogram for banana-XC589670 not found and could not be generated
# Warning: Spectrogram for grekis-XC147340 not found and could not be generatedWarning: Spectrogram for rinkin1-XC939808 not found and could not be generated
#
# Warning: Spectrogram for y00678-XC165328 not found and could not be generatedWarning: Spectrogram for greegr-XC490733 not found and could not be generated
#
# Warning: Spectrogram for compau-iNat891832 not found and could not be generatedWarning: Spectrogram for grekis-iNat303591 not found and could not be generated
#
# Warning: Spectrogram for compot1-iNat1214044 not found and could not be generatedWarning: Spectrogram for roahaw-XC401173 not found and could not be generated
#
# Warning: Spectrogram for laufal1-iNat286418 not found and could not be generatedWarning: Spectrogram for strcuc1-XC858650 not found and could not be generated
#
# Warning: Spectrogram for cargra1-iNat179120 not found and could not be generatedWarning: Spectrogram for yebela1-XC6548 not found and could not be generated
#
# Warning: Spectrogram for tbsfin1-XC480421 not found and could not be generatedWarning: Spectrogram for trokin-XC135490 not found and could not be generated
#
# Warning: Spectrogram for compau-iNat544375 not found and could not be generated
# Warning: Spectrogram for trokin-XC282578 not found and could not be generatedWarning: Spectrogram for littin1-XC839360 not found and could not be generated
#
# Warning: Spectrogram for cotfly1-XC955364 not found and could not be generatedWarning: Spectrogram for bubwre1-XC154170 not found and could not be generated
#
# Warning: Spectrogram for orcpar-iNat653427 not found and could not be generatedWarning: Spectrogram for strher-iNat1280880 not found and could not be generated
#
# Warning: Spectrogram for mastit1-XC361094 not found and could not be generatedWarning: Spectrogram for sobtyr1-XC789959 not found and could not be generated
#
# Warning: Spectrogram for smbani-XC122246 not found and could not be generatedWarning: Spectrogram for whbman1-XC532988 not found and could not be generated
#
# Warning: Spectrogram for laufal1-iNat578613 not found and could not be generatedWarning: Spectrogram for srwswa1-XC946235 not found and could not be generated
#
# Warning: Spectrogram for compau-iNat1217420 not found and could not be generatedWarning: Spectrogram for yebela1-XC533979 not found and could not be generated
#
# Warning: Spectrogram for orcpar-iNat82900 not found and could not be generatedWarning: Spectrogram for yeofly1-XC123601 not found and could not be generated
#
# Warning: Spectrogram for sobtyr1-XC771586 not found and could not be generated
# Warning: Spectrogram for smbani-XC213482 not found and could not be generatedWarning: Spectrogram for linwoo1-XC402747 not found and could not be generated
#
# Warning: Spectrogram for cotfly1-XC399478 not found and could not be generatedWarning: Spectrogram for strher-iNat868392 not found and could not be generated
#
# Warning: Spectrogram for compau-XC538254 not found and could not be generatedWarning: Spectrogram for blbgra1-XC946290 not found and could not be generated
#
# Warning: Spectrogram for rinkin1-XC148287 not found and could not be generated
# Warning: Spectrogram for watjac1-XC127237 not found and could not be generated
# Warning: Spectrogram for bbwduc-XC254938 not found and could not be generated
# Warning: Spectrogram for trokin-XC124253 not found and could not be generated
# Warning: Spectrogram for bkmtou1-XC34835 not found and could not be generated
# Warning: Spectrogram for roahaw-XC238998 not found and could not be generated
# Warning: Spectrogram for speowl1-XC534116 not found and could not be generated
# Warning: Spectrogram for colara1-XC439335 not found and could not be generated
# Warning: Spectrogram for socfly1-XC181682 not found and could not be generated
# Warning: Spectrogram for tropar-XC738222 not found and could not be generated
# Warning: Spectrogram for anhing-iNat51779 not found and could not be generated
# Warning: Spectrogram for recwoo1-XC433578 not found and could not be generated
# Warning: Spectrogram for littin1-XC656065 not found and could not be generated
# Warning: Spectrogram for cattyr-XC510643 not found and could not be generated
# Warning: Spectrogram for 787625-iNat117128 not found and could not be generated
# Warning: Spectrogram for strfly1-iNat320029 not found and could not be generated
# Warning: Spectrogram for yercac1-XC123261 not found and could not be generated
# Warning: Spectrogram for yeofly1-XC703847 not found and could not be generated
# Warning: Spectrogram for trokin-iNat665337 not found and could not be generated
# Warning: Spectrogram for rinkin1-XC415844 not found and could not be generated
# Warning: Spectrogram for compau-iNat729290 not found and could not be generated
# Warning: Spectrogram for 22976-iNat236359 not found and could not be generated
# Warning: Spectrogram for compot1-iNat557893 not found and could not be generated
# Warning: Spectrogram for soulap1-XC592819 not found and could not be generated
# Warning: Spectrogram for amekes-XC877035 not found and could not be generated
# Warning: Spectrogram for gycwor1-iNat1167705 not found and could not be generated
# Warning: Spectrogram for sobtyr1-XC855993 not found and could not be generated
# Warning: Spectrogram for thlsch3-XC608882 not found and could not be generated
# Warning: Spectrogram for soulap1-iNat351923 not found and could not be generated
# Warning: Spectrogram for bkcdon-XC120539 not found and could not be generated
# Warning: Spectrogram for banana-iNat1009822 not found and could not be generated
# Warning: Spectrogram for trokin-XC282372 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC32427 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC532528 not found and could not be generated
# Warning: Spectrogram for whtdov-iNat363910 not found and could not be generated
# Warning: Spectrogram for blkvul-XC127221 not found and could not be generated
# Warning: Spectrogram for secfly1-XC58256 not found and could not be generated
# Warning: Spectrogram for trsowl-iNat940159 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC393243 not found and could not be generated
# Warning: Spectrogram for yercac1-XC837303 not found and could not be generated
# Warning: Spectrogram for trokin-iNat355208 not found and could not be generated
# Warning: Spectrogram for gretin1-XC261511 not found and could not be generated
# Warning: Spectrogram for watjac1-XC48564 not found and could not be generated
# Warning: Spectrogram for compot1-XC355872 not found and could not be generated
# Warning: Spectrogram for bkmtou1-iNat896511 not found and could not be generated
# Warning: Spectrogram for gycwor1-iNat171427 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC386636 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC963351 not found and could not be generated
# Warning: Spectrogram for eardov1-XC212485 not found and could not be generated
# Warning: Spectrogram for greegr-XC627082 not found and could not be generated
# Warning: Spectrogram for rinkin1-XC716829 not found and could not be generated
# Warning: Spectrogram for blbwre1-XC9726 not found and could not be generated
# Warning: Spectrogram for compau-XC238690 not found and could not be generated
# Warning: Spectrogram for leagre-XC51130 not found and could not be generated
# Warning: Spectrogram for bkmtou1-XC495449 not found and could not be generated
# Warning: Spectrogram for cinbec1-XC166428 not found and could not be generated
# Warning: Spectrogram for compot1-XC186859 not found and could not be generated
# Warning: Spectrogram for saffin-XC755481 not found and could not be generated
# Warning: Spectrogram for tropar-XC814192 not found and could not be generated
# Warning: Spectrogram for whbman1-XC275503 not found and could not be generated
# Warning: Spectrogram for sobtyr1-XC285170 not found and could not be generated
# Warning: Spectrogram for whtdov-iNat83783 not found and could not be generated
# Warning: Spectrogram for grekis-XC306090 not found and could not be generated
# Warning: Spectrogram for creoro1-XC167967 not found and could not be generated
# Warning: Spectrogram for stbwoo2-XC353768 not found and could not be generated
# Warning: Spectrogram for gycwor1-XC713688 not found and could not be generated
# Warning: Spectrogram for greibi1-XC85214 not found and could not be generated
# Warning: Spectrogram for yercac1-XC493176 not found and could not be generated
# Warning: Spectrogram for chfmac1-XC196410 not found and could not be generated
# Warning: Spectrogram for solsan-XC662088 not found and could not be generated
# Warning: Spectrogram for stbwoo2-XC525028 not found and could not be generated
# Warning: Spectrogram for cocher1-XC550389 not found and could not be generated
# Warning: Spectrogram for bbwduc-XC709821 not found and could not be generated
# Warning: Spectrogram for speowl1-XC1955 not found and could not be generated
# Warning: Spectrogram for grekis-iNat82009 not found and could not be generated
# Warning: Spectrogram for blcant4-XC316967 not found and could not be generated
# Warning: Spectrogram for grekis-XC148226 not found and could not be generated
# Warning: Spectrogram for ruther1-XC274912 not found and could not be generated
# Warning: Spectrogram for whtdov-XC705809 not found and could not be generated
# Warning: Spectrogram for crcwoo1-XC295374 not found and could not be generated
# Warning: Spectrogram for rinkin1-XC286817 not found and could not be generated
# Warning: Spectrogram for speowl1-XC125425 not found and could not be generated
# Warning: Spectrogram for speowl1-XC922006 not found and could not be generated
# Warning: Spectrogram for gycwor1-iNat960583 not found and could not be generated
# Warning: Spectrogram for rutjac1-XC130918 not found and could not be generated
# Warning: Spectrogram for whbman1-XC643378 not found and could not be generated
# Warning: Spectrogram for yeofly1-XC893931 not found and could not be generated
# Warning: Spectrogram for thbeup1-iNat360364 not found and could not be generated
# Warning: Spectrogram for amekes-iNat749809 not found and could not be generated
# Warning: Spectrogram for creoro1-XC817267 not found and could not be generated
# Warning: Spectrogram for pirfly1-XC316770 not found and could not be generated
# Warning: Spectrogram for roahaw-iNat565901 not found and could not be generated
# Warning: Spectrogram for yeofly1-iNat888323 not found and could not be generated
# Warning: Spectrogram for leagre-iNat397678 not found and could not be generated
# Warning: Spectrogram for orcpar-iNat981063 not found and could not be generated
# Warning: Spectrogram for brtpar1-XC54667 not found and could not be generated
# Warning: Spectrogram for chbant1-XC730089 not found and could not be generated
# Warning: Spectrogram for cregua1-XC146737 not found and could not be generated
# Warning: Spectrogram for bobfly1-iNat100989 not found and could not be generated
# Warning: Spectrogram for rumfly1-iNat73206 not found and could not be generated
# Warning: Spectrogram for smbani-iNat560172 not found and could not be generated
# Warning: Spectrogram for yecspi2-XC460427 not found and could not be generated
# Warning: Spectrogram for strher-XC422990 not found and could not be generated
# Warning: Spectrogram for blcant4-XC467458 not found and could not be generated
# Warning: Spectrogram for butsal1-iNat52086 not found and could not be generated
# Warning: Spectrogram for littin1-iNat821734 not found and could not be generated
# Warning: Spectrogram for greegr-XC558126 not found and could not be generated
# Warning: Spectrogram for greegr-XC661723 not found and could not be generated
# Warning: Spectrogram for chfmac1-XC437960 not found and could not be generated
# Warning: Spectrogram for purgal2-iNat214589 not found and could not be generated
# Warning: Spectrogram for purgal2-XC196255 not found and could not be generated
# Warning: Spectrogram for socfly1-iNat920538 not found and could not be generated
# Warning: Spectrogram for orcpar-iNat649047 not found and could not be generated
# Warning: Spectrogram for rutjac1-XC447983 not found and could not be generated
# Warning: Spectrogram for soulap1-iNat616671 not found and could not be generated
# Warning: Spectrogram for rtlhum-XC447871 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC170124 not found and could not be generated
# Warning: Spectrogram for roahaw-XC363466 not found and could not be generated
# Warning: Spectrogram for bbwduc-XC900107 not found and could not be generated
# Warning: Spectrogram for bicwre1-XC387417 not found and could not be generated
# Warning: Spectrogram for roahaw-XC117179 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC747274 not found and could not be generated
# Warning: Spectrogram for littin1-XC674279 not found and could not be generated
# Warning: Spectrogram for trsowl-iNat1069834 not found and could not be generated
# Warning: Spectrogram for y00678-XC379558 not found and could not be generated
# Warning: Spectrogram for whtdov-iNat863170 not found and could not be generated
# Warning: Spectrogram for sahpar1-XC178654 not found and could not be generated
# Warning: Spectrogram for orcpar-iNat871299 not found and could not be generated
# Warning: Spectrogram for compau-iNat532880 not found and could not be generated
# Warning: Spectrogram for tropar-XC447689 not found and could not be generated
# Warning: Spectrogram for grbhaw1-XC612246 not found and could not be generated
# Warning: Spectrogram for yercac1-XC74694 not found and could not be generated
# Warning: Spectrogram for amekes-iNat337553 not found and could not be generated
# Warning: Spectrogram for 41663-iNat1127617 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC425848 not found and could not be generated
# Warning: Spectrogram for soulap1-iNat673146 not found and could not be generated
# Warning: Spectrogram for rugdov-XC690725 not found and could not be generated
# Warning: Spectrogram for bbwduc-iNat1068325 not found and could not be generated
# Warning: Spectrogram for 41663-iNat358212 not found and could not be generated
# Warning: Spectrogram for greani1-XC702055 not found and could not be generated
# Warning: Spectrogram for whmtyr1-XC803298 not found and could not be generated
# Warning: Spectrogram for banana-XC519808 not found and could not be generated
# Warning: Spectrogram for yehcar1-XC148233 not found and could not be generated
# Warning: Spectrogram for soulap1-XC713161 not found and could not be generated
# Warning: Spectrogram for bugtan-iNat818452 not found and could not be generated
# Warning: Spectrogram for bobfly1-XC219367 not found and could not be generated
# Warning: Spectrogram for paltan1-XC122348 not found and could not be generated
# Warning: Spectrogram for 65373-iNat78658 not found and could not be generated
# Warning: Spectrogram for stbwoo2-XC775556 not found and could not be generated
# Warning: Spectrogram for smbani-XC173686 not found and could not be generated
# Warning: Spectrogram for littin1-iNat321179 not found and could not be generated
# Warning: Spectrogram for bobfly1-XC581963 not found and could not be generated
# Warning: Spectrogram for bicwre1-XC246896 not found and could not be generated
# Warning: Spectrogram for grekis-iNat54437 not found and could not be generated
# Warning: Spectrogram for grnkin-iNat783601 not found and could not be generated
# Warning: Spectrogram for tropar-iNat537577 not found and could not be generated
# Warning: Spectrogram for compau-XC122296 not found and could not be generated
# Warning: Spectrogram for trokin-iNat456630 not found and could not be generated
# Warning: Spectrogram for laufal1-iNat190600 not found and could not be generated
# Warning: Spectrogram for yercac1-XC536711 not found and could not be generated
# Warning: Spectrogram for cotfly1-XC429032 not found and could not be generated
# Warning: Spectrogram for blcjay1-iNat34550 not found and could not be generated
# Warning: Spectrogram for banana-XC308451 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC559621 not found and could not be generated
# Warning: Spectrogram for snoegr-iNat838771 not found and could not be generated
# Warning: Spectrogram for rumfly1-XC118234 not found and could not be generated
# Warning: Spectrogram for 566513-iNat72467 not found and could not be generated
# Warning: Spectrogram for roahaw-XC502174 not found and could not be generated
# Warning: Spectrogram for blbwre1-XC278871 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC402632 not found and could not be generated
# Warning: Spectrogram for solsan-XC774172 not found and could not be generated
# Warning: Spectrogram for rumfly1-XC536761 not found and could not be generated
# Warning: Spectrogram for greani1-XC461444 not found and could not be generated
# Warning: Spectrogram for chbant1-XC17187 not found and could not be generated
# Warning: Spectrogram for rumfly1-XC248260 not found and could not be generated
# Warning: Spectrogram for rubsee1-XC690814 not found and could not be generated
# Warning: Spectrogram for wbwwre1-iNat291676 not found and could not be generated
# Warning: Spectrogram for roahaw-XC536457 not found and could not be generated
# Warning: Spectrogram for leagre-XC717579 not found and could not be generated
# Warning: Spectrogram for bobfly1-XC857531 not found and could not be generated
# Warning: Spectrogram for yebela1-XC955505 not found and could not be generated
# Warning: Spectrogram for grekis-iNat542282 not found and could not be generated
# Warning: Spectrogram for brtpar1-XC664255 not found and could not be generated
# Warning: Spectrogram for chfmac1-XC940551 not found and could not be generated
# Warning: Spectrogram for banana-iNat502581 not found and could not be generated
# Warning: Spectrogram for grekis-iNat82301 not found and could not be generated
# Warning: Spectrogram for butsal1-XC862318 not found and could not be generated
# Warning: Spectrogram for greani1-XC356487 not found and could not be generated
# Warning: Spectrogram for saffin-iNat91506 not found and could not be generated
# Warning: Spectrogram for strfly1-XC275473 not found and could not be generated
# Warning: Spectrogram for saffin-iNat1070741 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC579643 not found and could not be generated
# Warning: Spectrogram for blhpar1-XC826228 not found and could not be generated
# Warning: Spectrogram for grekis-iNat258009 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC216571 not found and could not be generated
# Warning: Spectrogram for grnkin-XC176853 not found and could not be generated
# Warning: Spectrogram for trsowl-iNat908201 not found and could not be generated
# Warning: Spectrogram for soulap1-iNat607072 not found and could not be generated
# Warning: Spectrogram for socfly1-XC333936 not found and could not be generated
# Warning: Spectrogram for strfly1-XC776322 not found and could not be generated
# Warning: Spectrogram for bbwduc-iNat1059144 not found and could not be generated
# Warning: Spectrogram for cregua1-XC489484 not found and could not be generated
# Warning: Spectrogram for cotfly1-XC54450 not found and could not be generated
# Warning: Spectrogram for strher-XC173408 not found and could not be generated
# Warning: Spectrogram for snoegr-XC705547 not found and could not be generated
# Warning: Spectrogram for yeofly1-XC568518 not found and could not be generated
# Warning: Spectrogram for compau-iNat914273 not found and could not be generated
# Warning: Spectrogram for laufal1-XC472336 not found and could not be generated
# Warning: Spectrogram for eardov1-XC513814 not found and could not be generated
# Warning: Spectrogram for strowl1-XC498203 not found and could not be generated
# Warning: Spectrogram for gycwor1-iNat72300 not found and could not be generated
# Warning: Spectrogram for trokin-XC361435 not found and could not be generated
# Warning: Spectrogram for trsowl-XC195105 not found and could not be generated
# Warning: Spectrogram for roahaw-iNat848403 not found and could not be generated
# Warning: Spectrogram for creoro1-XC424590 not found and could not be generated
# Warning: Spectrogram for rutjac1-XC261830 not found and could not be generated
# Warning: Spectrogram for whfant1-XC471956 not found and could not be generated
# Warning: Spectrogram for babwar-XC135079 not found and could not be generated
# Warning: Spectrogram for solsan-XC216149 not found and could not be generated
# Warning: Spectrogram for rubsee1-XC327349 not found and could not be generated
# Warning: Spectrogram for yercac1-XC302158 not found and could not be generated
# Warning: Spectrogram for labter1-XC794817 not found and could not be generated
# Warning: Spectrogram for trsowl-iNat254602 not found and could not be generated
# Warning: Spectrogram for piepuf1-XC782006 not found and could not be generated
# Warning: Spectrogram for amekes-iNat851727 not found and could not be generated
# Warning: Spectrogram for roahaw-XC344349 not found and could not be generated
# Warning: Spectrogram for amekes-XC362105 not found and could not be generated
# Warning: Spectrogram for blbgra1-iNat120777 not found and could not be generated
# Warning: Spectrogram for palhor2-XC685708 not found and could not be generated
# Warning: Spectrogram for orcpar-iNat207843 not found and could not be generated
# Warning: Spectrogram for bkcdon-XC830853 not found and could not be generated
# Warning: Spectrogram for creoro1-iNat607524 not found and could not be generated
# Warning: Spectrogram for roahaw-iNat392555 not found and could not be generated
# Warning: Spectrogram for plbwoo1-XC636082 not found and could not be generated
# Warning: Spectrogram for verfly-XC55047 not found and could not be generated
# Warning: Spectrogram for bobfly1-XC235874 not found and could not be generated
# Warning: Spectrogram for grekis-XC695309 not found and could not be generated
# Warning: Spectrogram for stbwoo2-XC202140 not found and could not be generated
# Warning: Spectrogram for tropar-XC147503 not found and could not be generated
# Warning: Spectrogram for roahaw-iNat605543 not found and could not be generated
# Warning: Spectrogram for cocwoo1-XC8220 not found and could not be generated
# Warning: Spectrogram for creoro1-XC428443 not found and could not be generated
# Warning: Spectrogram for linwoo1-XC803498 not found and could not be generated
# Warning: Spectrogram for compau-XC144472 not found and could not be generated
# Warning: Spectrogram for saffin-XC342570 not found and could not be generated
# Warning: Spectrogram for grasal4-iNat740466 not found and could not be generated
# Warning: Spectrogram for colara1-iNat24886 not found and could not be generated
# Warning: Spectrogram for bugtan-XC301212 not found and could not be generated
# Warning: Spectrogram for banana-iNat950352 not found and could not be generated
# Warning: Spectrogram for whtdov-iNat493027 not found and could not be generated
# Warning: Spectrogram for srwswa1-XC57304 not found and could not be generated
# Warning: Spectrogram for compot1-iNat1214038 not found and could not be generated
# Warning: Spectrogram for yecspi2-XC524938 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC704163 not found and could not be generated
# Warning: Spectrogram for strfly1-iNat683024 not found and could not be generated
# Warning: Spectrogram for strcuc1-XC55796 not found and could not be generated
# Warning: Spectrogram for bobfly1-XC533968 not found and could not be generated
# Warning: Spectrogram for 1462737-CSA36395 not found and could not be generated
# Warning: Spectrogram for bobfly1-iNat592336 not found and could not be generated
# Warning: Spectrogram for secfly1-XC708076 not found and could not be generated
# Warning: Spectrogram for yebfly1-XC769494 not found and could not be generated
# Warning: Spectrogram for 24272-iNat341657 not found and could not be generated
# Warning: Spectrogram for compau-XC197668 not found and could not be generated
# Warning: Spectrogram for whbant1-iNat48860 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC211524 not found and could not be generated
# Warning: Spectrogram for y00678-XC377780 not found and could not be generated
# Warning: Spectrogram for blcjay1-XC907194 not found and could not be generated
# Warning: Spectrogram for 21211-XC882648 not found and could not be generated
# Warning: Spectrogram for rufmot1-XC122269 not found and could not be generated
# Warning: Spectrogram for y00678-XC456643 not found and could not be generated
# Warning: Spectrogram for grekis-XC174442 not found and could not be generated
# Warning: Spectrogram for bicwre1-XC661028 not found and could not be generated
# Warning: Spectrogram for creoro1-XC386682 not found and could not be generated
# Warning: Spectrogram for whtdov-XC483309 not found and could not be generated
# Warning: Spectrogram for rumfly1-iNat524534 not found and could not be generated
# Warning: Spectrogram for saffin-XC50973 not found and could not be generated
# Warning: Spectrogram for soulap1-iNat139040 not found and could not be generated
# Warning: Spectrogram for yehcar1-XC826234 not found and could not be generated
# Warning: Spectrogram for compau-XC550069 not found and could not be generated
# Warning: Spectrogram for grekis-iNat490074 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC478804 not found and could not be generated
# Warning: Spectrogram for trsowl-iNat1238651 not found and could not be generated
# Warning: Spectrogram for grekis-iNat648914 not found and could not be generated
# Warning: Spectrogram for gybmar-XC407210 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC242768 not found and could not be generated
# Warning: Spectrogram for neocor-XC413298 not found and could not be generated
# Warning: Spectrogram for gycwor1-XC320351 not found and could not be generated
# Warning: Spectrogram for bbwduc-iNat839691 not found and could not be generated
# Warning: Spectrogram for blhpar1-XC525410 not found and could not be generated
# Warning: Spectrogram for trokin-XC705422 not found and could not be generated
# Warning: Spectrogram for creoro1-XC525013 not found and could not be generated
# Warning: Spectrogram for trokin-iNat828676 not found and could not be generated
# Warning: Spectrogram for bicwre1-XC385510 not found and could not be generated
# Warning: Spectrogram for smbani-XC269046 not found and could not be generated
# Warning: Spectrogram for grekis-XC812873 not found and could not be generated
# Warning: Spectrogram for mastit1-iNat757583 not found and could not be generated
# Warning: Spectrogram for yeofly1-XC2215 not found and could not be generated
# Warning: Spectrogram for grekis-XC803268 not found and could not be generated
# Warning: Spectrogram for blbwre1-XC335112 not found and could not be generated
# Warning: Spectrogram for grbhaw1-XC117428 not found and could not be generated
# Warning: Spectrogram for sobtyr1-XC303846 not found and could not be generated
# Warning: Spectrogram for shtfly1-XC835870 not found and could not be generated
# Warning: Spectrogram for 67252-XC882999 not found and could not be generated
# Warning: Spectrogram for soulap1-XC304263 not found and could not be generated
# Warning: Spectrogram for grekis-iNat1287703 not found and could not be generated
# Warning: Spectrogram for linwoo1-XC238247 not found and could not be generated
# Warning: Spectrogram for gycwor1-XC391195 not found and could not be generated
# Warning: Spectrogram for greani1-XC279498 not found and could not be generated
# Warning: Spectrogram for yebfly1-XC428095 not found and could not be generated
# Warning: Spectrogram for cocher1-XC466556 not found and could not be generated
# Warning: Spectrogram for srwswa1-XC863386 not found and could not be generated
# Warning: Spectrogram for rinkin1-XC419474 not found and could not be generated
# Warning: Spectrogram for bugtan-iNat150282 not found and could not be generated
# Warning: Spectrogram for piepuf1-XC456442 not found and could not be generated
# Warning: Spectrogram for bucmot3-XC657456 not found and could not be generated
# Warning: Spectrogram for creoro1-XC245390 not found and could not be generated
# Warning: Spectrogram for rubsee1-XC524082 not found and could not be generated
# Warning: Spectrogram for eardov1-iNat310743 not found and could not be generated
# Warning: Spectrogram for leagre-XC435990 not found and could not be generated
# Warning: Spectrogram for bbwduc-iNat597864 not found and could not be generated
# Warning: Spectrogram for grekis-iNat494927 not found and could not be generated
# Warning: Spectrogram for saffin-XC562696 not found and could not be generated
# Warning: Spectrogram for rebbla1-XC221570 not found and could not be generated
# Warning: Spectrogram for compau-iNat936765 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC482717 not found and could not be generated
# Warning: Spectrogram for whtdov-iNat52709 not found and could not be generated
# Warning: Spectrogram for smbani-XC257725 not found and could not be generated
# Warning: Spectrogram for compau-iNat887681 not found and could not be generated
# Warning: Spectrogram for speowl1-XC642361 not found and could not be generated
# Warning: Spectrogram for 517119-iNat402787 not found and could not be generated
# Warning: Spectrogram for trokin-XC713687 not found and could not be generated
# Warning: Spectrogram for rtlhum-XC261741 not found and could not be generated
# Warning: Spectrogram for banana-XC233959 not found and could not be generated
# Warning: Spectrogram for blhpar1-XC509485 not found and could not be generated
# Warning: Spectrogram for trsowl-iNat621391 not found and could not be generated
# Warning: Spectrogram for verfly-iNat962047 not found and could not be generated
# Warning: Spectrogram for yebfly1-XC428096 not found and could not be generated
# Warning: Spectrogram for watjac1-XC257497 not found and could not be generated
# Warning: Spectrogram for 22333-iNat255294 not found and could not be generated
# Warning: Spectrogram for compau-XC336198 not found and could not be generated
# Warning: Spectrogram for rutjac1-XC496090 not found and could not be generated
# Warning: Spectrogram for grekis-XC467087 not found and could not be generated
# Warning: Spectrogram for srwswa1-XC518146 not found and could not be generated
# Warning: Spectrogram for bubwre1-iNat1020464 not found and could not be generated
# Warning: Spectrogram for amekes-iNat1237265 not found and could not be generated
# Warning: Spectrogram for yebela1-XC81537 not found and could not be generated
# Warning: Spectrogram for yehcar1-XC211159 not found and could not be generated
# Warning: Spectrogram for yercac1-iNat1215366 not found and could not be generated
# Warning: Spectrogram for strfly1-XC673328 not found and could not be generated
# Warning: Spectrogram for crebob1-XC139476 not found and could not be generated
# Warning: Spectrogram for rufmot1-XC446712 not found and could not be generated
# Warning: Spectrogram for bugtan-XC261223 not found and could not be generated
# Warning: Spectrogram for grbhaw1-XC13334 not found and could not be generated
# Warning: Spectrogram for cotfly1-XC524950 not found and could not be generated
# Warning: Spectrogram for 65344-iNat923979 not found and could not be generated
# Warning: Spectrogram for banana-XC115505 not found and could not be generated
# Warning: Spectrogram for socfly1-iNat1008696 not found and could not be generated
# Warning: Spectrogram for trokin-XC163744 not found and could not be generated
# Warning: Spectrogram for blhpar1-XC477319 not found and could not be generated
# Warning: Spectrogram for bobfly1-XC427567 not found and could not be generated
# Warning: Spectrogram for compau-iNat559416 not found and could not be generated
# Warning: Spectrogram for greani1-XC591114 not found and could not be generated
# Warning: Spectrogram for bobfly1-iNat925739 not found and could not be generated
# Warning: Spectrogram for bbwduc-XC622464 not found and could not be generated
# Warning: Spectrogram for strher-XC257323 not found and could not be generated
# Warning: Spectrogram for trokin-iNat1274107 not found and could not be generated
# Warning: Spectrogram for compau-iNat414732 not found and could not be generated
# Warning: Spectrogram for greani1-XC257718 not found and could not be generated
# Warning: Spectrogram for roahaw-XC520781 not found and could not be generated
# Warning: Spectrogram for laufal1-XC823755 not found and could not be generated
# Warning: Spectrogram for chbant1-XC353927 not found and could not be generated
# Warning: Spectrogram for trokin-XC841639 not found and could not be generated
# Warning: Spectrogram for bbwduc-iNat580822 not found and could not be generated
# Warning: Spectrogram for whtdov-XC290367 not found and could not be generated
# Warning: Spectrogram for roahaw-XC925791 not found and could not be generated
# Warning: Spectrogram for trsowl-XC676376 not found and could not be generated
# Warning: Spectrogram for chfmac1-XC893662 not found and could not be generated
# Warning: Spectrogram for chfmac1-XC519607 not found and could not be generated
# Warning: Spectrogram for sobtyr1-XC531440 not found and could not be generated
# Warning: Spectrogram for srwswa1-XC143417 not found and could not be generated
#
# Warning: Spectrogram for trokin-iNat844220 not found and could not be generatedWarning: Spectrogram for ywcpar-XC213240 not found and could not be generated
# Warning: Spectrogram for littin1-XC387848 not found and could not be generated
# Warning: Spectrogram for strfly1-XC293828 not found and could not be generated
# Warning: Spectrogram for grekis-XC424597 not found and could not be generated
# Warning: Spectrogram for orcpar-XC162236 not found and could not be generated
# Warning: Spectrogram for banana-XC775648 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC242769 not found and could not be generated
# Warning: Spectrogram for yebela1-iNat261764 not found and could not be generated
# Warning: Spectrogram for compau-XC215199 not found and could not be generated
# Warning: Spectrogram for yeofly1-iNat297828 not found and could not be generated
# Warning: Spectrogram for trokin-XC767435 not found and could not be generated
# Warning: Spectrogram for tropar-XC253542 not found and could not be generated
# Warning: Spectrogram for fotfly-XC443542 not found and could not be generated
# Warning: Spectrogram for greegr-XC307659 not found and could not be generated
# Warning: Spectrogram for gybmar-iNat214837 not found and could not be generated
# Warning: Spectrogram for baymac-XC274941 not found and could not be generated
# Warning: Spectrogram for rugdov-XC925782 not found and could not be generated
# Warning: Spectrogram for socfly1-XC245559 not found and could not be generated
# Warning: Spectrogram for banana-XC287776 not found and could not be generated
# Warning: Spectrogram for bbwduc-XC824006 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC541894 not found and could not be generated
# Warning: Spectrogram for 22976-iNat226804 not found and could not be generated
# Warning: Spectrogram for yebela1-XC387065 not found and could not be generated
# Warning: Spectrogram for pirfly1-XC744701 not found and could not be generated
# Warning: Spectrogram for trokin-XC609459 not found and could not be generated
# Warning: Spectrogram for solsan-XC188937 not found and could not be generated
# Warning: Spectrogram for yeofly1-XC609689 not found and could not be generated
# Warning: Spectrogram for strfly1-XC286535 not found and could not be generated
# Warning: Spectrogram for roahaw-iNat849296 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC898225 not found and could not be generated
# Warning: Spectrogram for grysee1-XC745119 not found and could not be generated
# Warning: Spectrogram for rtlhum-XC47068 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC398968 not found and could not be generated
# Warning: Spectrogram for stbwoo2-XC385724 not found and could not be generated
# Warning: Spectrogram for bkmtou1-XC425547 not found and could not be generated
# Warning: Spectrogram for thbeup1-XC245421 not found and could not be generated
# Warning: Spectrogram for solsan-iNat1011634 not found and could not be generated
# Warning: Spectrogram for saffin-XC617906 not found and could not be generated
# Warning: Spectrogram for 21211-XC882658 not found and could not be generated
# Warning: Spectrogram for bbwduc-XC492409 not found and could not be generated
# Warning: Spectrogram for laufal1-XC812887 not found and could not be generated
# Warning: Spectrogram for solsan-XC197064 not found and could not be generated
# Warning: Spectrogram for 22976-iNat843264 not found and could not be generated
# Warning: Spectrogram for greegr-iNat914914 not found and could not be generated
# Warning: Spectrogram for butsal1-iNat398142 not found and could not be generated
# Warning: Spectrogram for saffin-XC64186 not found and could not be generated
# Warning: Spectrogram for trokin-XC401177 not found and could not be generated
# Warning: Spectrogram for speowl1-XC783219 not found and could not be generated
# Warning: Spectrogram for saffin-XC359236 not found and could not be generated
# Warning: Spectrogram for grekis-iNat56944 not found and could not be generated
# Warning: Spectrogram for yehcar1-XC433374 not found and could not be generated
# Warning: Spectrogram for blcjay1-XC393120 not found and could not be generated
# Warning: Spectrogram for compau-XC388101 not found and could not be generated
# Warning: Spectrogram for trokin-iNat342388 not found and could not be generated
# Warning: Spectrogram for socfly1-iNat322454 not found and could not be generated
# Warning: Spectrogram for trokin-XC345790 not found and could not be generated
# Warning: Spectrogram for bkmtou1-iNat933224 not found and could not be generated
# Warning: Spectrogram for blbwre1-XC178613 not found and could not be generated
# Warning: Spectrogram for roahaw-XC723139 not found and could not be generated
# Warning: Spectrogram for compau-XC861510 not found and could not be generated
# Warning: Spectrogram for grekis-XC180321 not found and could not be generated
# Warning: Spectrogram for stbwoo2-XC656960 not found and could not be generated
# Warning: Spectrogram for yecspi2-XC648685 not found and could not be generated
# Warning: Spectrogram for rebbla1-XC257157 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC397540 not found and could not be generated
# Warning: Spectrogram for cattyr-XC221040 not found and could not be generated
# Warning: Spectrogram for bugtan-iNat76216 not found and could not be generated
# Warning: Spectrogram for amekes-iNat190634 not found and could not be generated
# Warning: Spectrogram for trokin-iNat1249856 not found and could not be generated
# Warning: Spectrogram for bkcdon-XC175768 not found and could not be generated
# Warning: Spectrogram for compot1-XC155788 not found and could not be generated
# Warning: Spectrogram for cargra1-XC582525 not found and could not be generated
# Warning: Spectrogram for roahaw-XC112988 not found and could not be generated
# Warning: Spectrogram for rebbla1-XC346174 not found and could not be generated
# Warning: Spectrogram for gycwor1-XC418185 not found and could not be generated
# Warning: Spectrogram for whtdov-XC744334 not found and could not be generated
# Warning: Spectrogram for compau-XC391615 not found and could not be generated
# Warning: Spectrogram for greibi1-XC705012 not found and could not be generated
# Warning: Spectrogram for solsan-iNat123565 not found and could not be generated
# Warning: Spectrogram for rutjac1-XC308313 not found and could not be generated
# Warning: Spectrogram for bkmtou1-iNat583107 not found and could not be generated
# Warning: Spectrogram for gretin1-XC257240 not found and could not be generated
# Warning: Spectrogram for grekis-XC47777 not found and could not be generated
# Warning: Spectrogram for saffin-iNat145877 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC259377 not found and could not be generated
# Warning: Spectrogram for blhpar1-XC483140 not found and could not be generated
# Warning: Spectrogram for trokin-iNat458454 not found and could not be generated
# Warning: Spectrogram for socfly1-iNat857271 not found and could not be generated
# Warning: Spectrogram for compot1-iNat1214032 not found and could not be generated
# Warning: Spectrogram for linwoo1-XC213015 not found and could not be generated
# Warning: Spectrogram for plbwoo1-XC841730 not found and could not be generated
# Warning: Spectrogram for neocor-XC177197 not found and could not be generated
# Warning: Spectrogram for shtfly1-XC680225 not found and could not be generated
# Warning: Spectrogram for fotfly-XC589561 not found and could not be generated
# ...
# Warning: Spectrogram for 22976-iNat843264 not found and could not be generated
# Warning: Spectrogram for thbeup1-XC762549 not found and could not be generated
# Warning: Spectrogram for socfly1-XC56172 not found and could not be generated
# Warning: Spectrogram for strher-XC756439 not found and could not be generated
# Warning: Spectrogram for eardov1-iNat376841 not found and could not be generated
# Warning: Spectrogram for tropar-iNat537577 not found and could not be generated
# Warning: Spectrogram for y00678-XC428810 not found and could not be generated
# Warning: Spectrogram for pirfly1-XC183921 not found and could not be generated
# Warning: Spectrogram for socfly1-iNat341933 not found and could not be generated
# Warning: Spectrogram for creoro1-XC817267 not found and could not be generated
# Warning: Spectrogram for gycwor1-XC418185 not found and could not be generated
# Warning: Spectrogram for amekes-XC362105 not found and could not be generated
# Warning: Spectrogram for grbhaw1-iNat1243503 not found and could not be generated
# Warning: Spectrogram for grnkin-iNat783601 not found and could not be generated
# Warning: Spectrogram for bobfly1-XC186434 not found and could not be generated
# Warning: Spectrogram for creoro1-XC428443 not found and could not be generated
# Warning: Spectrogram for wbwwre1-iNat291676 not found and could not be generated
# Warning: Spectrogram for banana-XC382368 not found and could not be generated
# Warning: Spectrogram for laufal1-XC203214 not found and could not be generated
# Warning: Spectrogram for ruther1-XC274912 not found and could not be generated
# Warning: Spectrogram for 22333-iNat255294 not found and could not be generated
# Warning: Spectrogram for wbwwre1-XC185739 not found and could not be generated
# Warning: Spectrogram for banana-XC233959 not found and could not be generated
# Warning: Spectrogram for grnkin-XC400957 not found and could not be generated
# Warning: Spectrogram for strfly1-XC776322 not found and could not be generated
# Warning: Spectrogram for soulap1-iNat139040 not found and could not be generated
# Warning: Spectrogram for soulap1-XC713161 not found and could not be generated
# Warning: Spectrogram for roahaw-XC117319 not found and could not be generated
# Warning: Spectrogram for cotfly1-XC429032 not found and could not be generated
# Warning: Spectrogram for trokin-XC308701 not found and could not be generated
# Warning: Spectrogram for trokin-XC460842 not found and could not be generated
# Warning: Spectrogram for trokin-iNat458454 not found and could not be generated
# Warning: Spectrogram for bkcdon-XC733946 not found and could not be generated
# Warning: Spectrogram for blbgra1-XC610515 not found and could not be generated
# Warning: Spectrogram for gycwor1-XC391195 not found and could not be generated
# Warning: Spectrogram for laufal1-XC472336 not found and could not be generated
# Warning: Spectrogram for spepar1-XC114161 not found and could not be generated
# Warning: Spectrogram for trsowl-iNat908201 not found and could not be generated
# Warning: Spectrogram for gycwor1-XC274932 not found and could not be generated
# Warning: Spectrogram for whtdov-iNat863170 not found and could not be generated
# Warning: Spectrogram for cinbec1-XC389682 not found and could not be generated
# Warning: Spectrogram for 67252-XC882999 not found and could not be generated
# Warning: Spectrogram for yecspi2-XC648685 not found and could not be generated
# Warning: Spectrogram for gycwor1-iNat171427 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC50099 not found and could not be generated
# Warning: Spectrogram for tropar-XC253542 not found and could not be generated
# Warning: Spectrogram for orcpar-iNat82900 not found and could not be generated
# Warning: Spectrogram for linwoo1-XC176365 not found and could not be generated
# Warning: Spectrogram for y00678-XC379558 not found and could not be generated
# Warning: Spectrogram for bkmtou1-XC261867 not found and could not be generated
# Warning: Spectrogram for yercac1-XC74694 not found and could not be generated
# Warning: Spectrogram for socfly1-XC181682 not found and could not be generated
# Warning: Spectrogram for trokin-XC841639 not found and could not be generated
# Warning: Spectrogram for strher-XC946035 not found and could not be generated
# Warning: Spectrogram for compau-XC388101 not found and could not be generated
# Warning: Spectrogram for rinkin1-XC716829 not found and could not be generated
# Warning: Spectrogram for chbant1-XC353927 not found and could not be generated
# Warning: Spectrogram for compau-XC247997 not found and could not be generated
# Warning: Spectrogram for smbani-XC818680 not found and could not be generated
# Warning: Spectrogram for compau-iNat559416 not found and could not be generated
# Warning: Spectrogram for gretin1-XC257240 not found and could not be generated
# Warning: Spectrogram for saffin-iNat91506 not found and could not be generated
# Warning: Spectrogram for bobfly1-XC581963 not found and could not be generated
# Warning: Spectrogram for tropar-XC926988 not found and could not be generated
# Warning: Spectrogram for creoro1-iNat607524 not found and could not be generated
# Warning: Spectrogram for 566513-iNat72467 not found and could not be generated
# Warning: Spectrogram for blcjay1-XC393120 not found and could not be generated
# Warning: Spectrogram for thbeup1-XC737983 not found and could not be generated
# Warning: Spectrogram for fotfly-XC457250 not found and could not be generated
# Warning: Spectrogram for neocor-XC277474 not found and could not be generated
# Warning: Spectrogram for bbwduc-iNat1068325 not found and could not be generated
# Warning: Spectrogram for compau-XC861506 not found and could not be generated
# Warning: Spectrogram for grekis-XC645147 not found and could not be generated
# Warning: Spectrogram for recwoo1-XC540103 not found and could not be generated
# Warning: Spectrogram for bbwduc-XC900107 not found and could not be generated
# Warning: Spectrogram for whttro1-XC252122 not found and could not be generated
# Warning: Spectrogram for bkcdon-XC120539 not found and could not be generated
# Warning: Spectrogram for leagre-iNat397678 not found and could not be generated
# Warning: Spectrogram for whbman1-XC275503 not found and could not be generated
# Warning: Spectrogram for greani1-XC461444 not found and could not be generated
# Warning: Spectrogram for banana-XC523834 not found and could not be generated
# Warning: Spectrogram for rtlhum-XC261741 not found and could not be generated
# Warning: Spectrogram for yehcar1-XC148233 not found and could not be generated
# Warning: Spectrogram for whtdov-XC183287 not found and could not be generated
# Warning: Spectrogram for rutjac1-XC2695 not found and could not be generated
# Warning: Spectrogram for solsan-XC216149 not found and could not be generated
# Warning: Spectrogram for butsal1-XC164544 not found and could not be generated
# Warning: Spectrogram for whbant1-iNat48860 not found and could not be generated
# Warning: Spectrogram for rumfly1-XC244949 not found and could not be generated
# Warning: Spectrogram for thbeup1-XC594859 not found and could not be generated
# Warning: Spectrogram for bbwduc-XC492409 not found and could not be generated
# Warning: Spectrogram for amekes-iNat190634 not found and could not be generated
# Warning: Spectrogram for gybmar-iNat214837 not found and could not be generated
# Warning: Spectrogram for sobtyr1-XC582634 not found and could not be generated
# Warning: Spectrogram for banana-XC775648 not found and could not be generated
# Warning: Spectrogram for amekes-iNat851727 not found and could not be generated
# Warning: Spectrogram for bicwre1-XC387417 not found and could not be generated
# Warning: Spectrogram for crbtan1-XC423493 not found and could not be generated
# Warning: Spectrogram for yeofly1-XC166050 not found and could not be generated
# Warning: Spectrogram for 65344-iNat923979 not found and could not be generated
# Warning: Spectrogram for laufal1-XC552716 not found and could not be generated
# Warning: Spectrogram for compau-iNat544375 not found and could not be generated
# Warning: Spectrogram for compau-XC122296 not found and could not be generated
# Warning: Spectrogram for bbwduc-XC622464 not found and could not be generated
# Warning: Spectrogram for wbwwre1-iNat301988 not found and could not be generated
# Warning: Spectrogram for ywcpar-XC213240 not found and could not be generated
# Warning: Spectrogram for butsal1-iNat398142 not found and could not be generated
# Warning: Spectrogram for blchaw1-XC656900 not found and could not be generated
# Warning: Spectrogram for cotfly1-XC524950 not found and could not be generated
# Warning: Spectrogram for secfly1-XC58256 not found and could not be generated
# Warning: Spectrogram for laufal1-iNat190599 not found and could not be generated
# Warning: Spectrogram for yeofly1-XC859242 not found and could not be generated
# Warning: Spectrogram for compau-iNat696309 not found and could not be generated
# Warning: Spectrogram for yebfly1-XC830728 not found and could not be generated
# Warning: Spectrogram for creoro1-XC114257 not found and could not be generated
# Warning: Spectrogram for trokin-XC135490 not found and could not be generated
# Warning: Spectrogram for piepuf1-XC456442 not found and could not be generated
# Warning: Spectrogram for speowl1-XC719818 not found and could not be generated
# Warning: Spectrogram for brtpar1-XC54667 not found and could not be generated
# Warning: Spectrogram for blhpar1-XC380712 not found and could not be generated
# Warning: Spectrogram for creoro1-XC132042 not found and could not be generated
# Warning: Spectrogram for yeofly1-iNat297828 not found and could not be generated
# Warning: Spectrogram for cocwoo1-iNat650332 not found and could not be generated
# Warning: Spectrogram for laufal1-XC812887 not found and could not be generated
# Warning: Spectrogram for bbwduc-iNat261161 not found and could not be generated
# Warning: Spectrogram for rinkin1-XC939808 not found and could not be generated
# Warning: Spectrogram for whbman1-XC317180 not found and could not be generated
# Warning: Spectrogram for chbant1-XC199004 not found and could not be generated
# Warning: Spectrogram for roahaw-iNat42251 not found and could not be generated
# Warning: Spectrogram for gycwor1-iNat960583 not found and could not be generated
# Warning: Spectrogram for compot1-XC186859 not found and could not be generated
# Warning: Spectrogram for trokin-iNat342388 not found and could not be generated
# Warning: Spectrogram for 517119-iNat402787 not found and could not be generated
# Warning: Spectrogram for rtlhum-XC312441 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC759613 not found and could not be generated
# Warning: Spectrogram for 65373-XC882751 not found and could not be generated
# Warning: Spectrogram for cocwoo1-XC8220 not found and could not be generated
# Warning: Spectrogram for savhaw1-XC51330 not found and could not be generated
# Warning: Spectrogram for 41778-XC959831 not found and could not be generated
# Warning: Spectrogram for yeofly1-XC123601 not found and could not be generated
# Warning: Spectrogram for grnkin-XC452701 not found and could not be generated
# Warning: Spectrogram for trokin-iNat456630 not found and could not be generated
# Warning: Spectrogram for ragmac1-XC433181 not found and could not be generated
# Warning: Spectrogram for mastit1-iNat227747 not found and could not be generated
# Warning: Spectrogram for grekis-iNat303591 not found and could not be generated
# Warning: Spectrogram for greegr-XC338469 not found and could not be generated
# Warning: Spectrogram for compot1-XC766531 not found and could not be generated
# Warning: Spectrogram for greani1-XC54796 not found and could not be generated
# Warning: Spectrogram for cotfly1-XC399478 not found and could not be generated
# Warning: Spectrogram for socfly1-iNat546244 not found and could not be generated
# Warning: Spectrogram for creoro1-iNat1205442 not found and could not be generated
# Warning: Spectrogram for tropar-XC235229 not found and could not be generated
# Warning: Spectrogram for soulap1-iNat673146 not found and could not be generated
# Warning: Spectrogram for bicwre1-XC385510 not found and could not be generated
# Warning: Spectrogram for blchaw1-XC115712 not found and could not be generated
# Warning: Spectrogram for grekis-iNat320785 not found and could not be generated
# Warning: Spectrogram for grasal4-iNat740466 not found and could not be generated
# Warning: Spectrogram for strher-XC173408 not found and could not be generated
# Warning: Spectrogram for whtdov-iNat52709 not found and could not be generated
# Warning: Spectrogram for soulap1-XC114069 not found and could not be generated
# Warning: Spectrogram for yercac1-iNat1215366 not found and could not be generated
# Warning: Spectrogram for laufal1-iNat190600 not found and could not be generated
# Warning: Spectrogram for gybmar-iNat214836 not found and could not be generated
# Warning: Spectrogram for brtpar1-XC664255 not found and could not be generated
# Warning: Spectrogram for bobfly1-XC427567 not found and could not be generated
# Warning: Spectrogram for whwswa1-XC475352 not found and could not be generated
# Warning: Spectrogram for solsan-XC197064 not found and could not be generated
# Warning: Spectrogram for amekes-XC877035 not found and could not be generated
# Warning: Spectrogram for rutjac1-XC754909 not found and could not be generated
# Warning: Spectrogram for pavpig2-XC707531 not found and could not be generated
# Warning: Spectrogram for grekis-iNat82009 not found and could not be generated
# Warning: Spectrogram for rumfly1-XC956038 not found and could not be generated
# Warning: Spectrogram for srwswa1-XC143417 not found and could not be generated
# Warning: Spectrogram for 42007-iNat141493 not found and could not be generated
# Warning: Spectrogram for yeofly1-XC843446 not found and could not be generated
# Warning: Spectrogram for 566513-iNat475442 not found and could not be generated
# Warning: Spectrogram for whtdov-iNat493027 not found and could not be generated
# Warning: Spectrogram for palhor2-XC685708 not found and could not be generated
# Warning: Spectrogram for blhpar1-XC521022 not found and could not be generated
# Warning: Spectrogram for butsal1-XC582955 not found and could not be generated
# Warning: Spectrogram for amekes-iNat522505 not found and could not be generated
# Warning: Spectrogram for tbsfin1-iNat68779 not found and could not be generated
# Warning: Spectrogram for solsan-XC123667 not found and could not be generated
# Warning: Spectrogram for bobfly1-iNat925739 not found and could not be generated
# Warning: Spectrogram for grekis-XC306090 not found and could not be generated
# Warning: Spectrogram for strcuc1-XC257732 not found and could not be generated
# Warning: Spectrogram for greani1-XC279498 not found and could not be generated
# Warning: Spectrogram for bubwre1-XC388387 not found and could not be generated
# Warning: Spectrogram for rufmot1-XC119538 not found and could not be generated
# Warning: Spectrogram for rugdov-XC925782 not found and could not be generated
# Warning: Spectrogram for whbant1-XC664405 not found and could not be generated
# Warning: Spectrogram for grekis-XC803268 not found and could not be generated
# Warning: Spectrogram for colara1-iNat24886 not found and could not be generated
# Warning: Spectrogram for banana-XC589670 not found and could not be generated
# Warning: Spectrogram for compau-XC811729 not found and could not be generated
# Warning: Spectrogram for laufal1-XC823755 not found and could not be generated
# Warning: Spectrogram for baymac-XC393347 not found and could not be generated
# Validation:   0%|          | 0/32 [00:00<?, ?it/s]
# Train Loss: 0.0319, Train AUC: 0.4775
# Val Loss: 0.0334, Val AUC: 0.4998
#
# Best AUC for fold 0: 0.5010 at epoch 1
#
# ============================================================
# Cross-Validation Results:
# Fold 0: 0.5010
# Mean AUC: 0.5010
# ============================================================
#
# Training complete!
